# %% [markdown]
# <a href="https://colab.research.google.com/github/djcoraanco/FossFLOW2/blob/master/fooocus_colab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Instalar uv y crear entorno limpio en Python 3.10
# !rm -rf /content/fooocus_env
# !pip install -q uv
# !uv venv /content/fooocus_env --python 3.10 --seed

# 2. Instalar PyTorch y torchvision compilados para CUDA 12
# !uv pip install --python /content/fooocus_env/bin/python torch torchvision --index-url https://download.pytorch.org/whl/cu121

# %%
# 1. Clonar el repositorio
# %cd /content
![ ! -d "Fooocus" ] && git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# 2. Instalar los paquetes base del repositorio
# !uv pip install --python /content/fooocus_env/bin/python -r requirements_versions.txt

# 3. Fijar el stack web compatible con Gradio 3.41.2 (evita errores ASGI y Pydantic v2)
# !uv pip install --python /content/fooocus_env/bin/python "pydantic==1.10.17" "fastapi==0.99.1" "starlette==0.27.0"

# %%
# %cd /content/Fooocus
# Iniciar con renderizador sin display (Agg) para evitar el conflicto de Matplotlib en Colab
# !MPLBACKEND=Agg /content/fooocus_env/bin/python launch.py --share
